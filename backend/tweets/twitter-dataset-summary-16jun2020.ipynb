# %% [markdown]
# ### Set up and load data

# %%
import pandas as pd
import numpy as np
import os
from pipelines import TwitterPipeline
from datasets import load_tweets, load_annotated_tweets
from tweet_map_counts import generate_map_counts

# %%
# Set parameters for plotting
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set(context="notebook")

# %%
# Load in the tweets
tweets = load_tweets()
tweets = TwitterPipeline().apply(tweets.data, verbosity=2)
annotations = load_annotated_tweets()
# Out:
# /Users/Nina/opt/miniconda3/envs/covid-community/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (0,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Filter Tweets from Wales.....completed in 0:00:01.571779
# Combine Text fields.....completed in 0:00:00.619944
# Convert Geo Coordinates (in Floating Point).....completed in 0:00:02.538798
# Collect BoundingBox Coordinates (GeoJSON).....completed in 0:00:07.137856
# Collect BoundingBox Coordinates (Tuples).....completed in 0:00:01.485183
# Match Local Authorities...
# /Users/Nina/Documents/Repositories/covid-communities/COVID-19-Community-Response/backend/tweets/pipelines.py:302: UserWarning: Dropped rows, due to no LA match
#   warn("Dropped rows, due to no LA match")
# ..completed in 0:01:44.597001
# Set DateTime Index.....completed in 0:02:18.022359

# %%
# Get tweets from March 1st onwards
tweets = tweets.loc['2020-03-01':]

# %%
# Plot of tweets by day
tweets["id_str"].resample("D").count().plot()

# %%
id_str = tweets["id_str"]

# %%
id_str.drop_duplicates(inplace=True)
# Get number of unique id strings 
id_str.shape
